# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv('Clean_Employees.csv')
df
# Out:
#     EmployeeID     EmployeeName                       Email   Department  \
# 0            1     Bob Williams     fatimabrown@example.com  Engineering
# 1            2       Omar Smith       meimiller@example.com  Engineering
# 2            4     Fatima Smith     fatimabrown@example.com      Support
# 3            5     Alice Miller      alicebrown@example.com        Sales
# 4            9     Carlos Smith       liamsmith@example.com           Hr
# ..         ...              ...                         ...          ...
# 58          92  Fatima Williams      alicesmith@example.com  Engineering
# 59          93     Alice Garcia  carlosmartinez@example.com        Sales
# 60          96     Priya Miller      alicesmith@example.com           Hr
# 61          97         Omar Lee       liamdavis@example.com           Hr
# 62         100       Mei Garcia   alicemartinez@example.com        Sales
#
#       Position    Salary    HireDate
# 0    Developer   75317.5  2021-07-15
# 1   not stated   30000.0  2020-05-10
# 2    Team Lead   30000.0  2021-02-28
# 3        Clerk   50000.0  2021-07-15
# 4   not stated   75317.5  2021-07-15
# ..         ...       ...         ...
# 58   Team Lead   60000.0  2020-05-10
# 59     Analyst   50000.0  2021-07-15
# 60   Developer   75317.5  2021-02-28
# 61     Analyst  100000.0  2021-02-28
# 62     Manager   60000.0  2021-02-28
#
# [63 rows x 7 columns]

# %%
sns.histplot(data=df,x='Salary',kde=True,bins=50)
plt.show()
