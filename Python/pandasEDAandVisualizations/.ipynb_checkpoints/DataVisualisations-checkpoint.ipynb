# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('employee_dataset.csv')
df
# Out:
#       EmployeeID    HireDate      Gender  Age        Department  \
# 0              1  2019-03-25        Male   58  Customer Support
# 1              2  2022-10-11        Male   39       Engineering
# 2              3  2020-02-03  Non-binary   39                HR
# 3              4  2015-03-21        Male   35       Engineering
# 4              5  2020-04-14        Male   56       Engineering
# ...          ...         ...         ...  ...               ...
# 4995        4996  2017-12-24  Non-binary   52       Engineering
# 4996        4997  2020-09-26      Female   63           Finance
# 4997        4998  2019-07-16      Female   50                HR
# 4998        4999  2016-03-01      Female   32             Sales
# 4999        5000  2016-04-04  Non-binary   44           Finance
#
#               JobRole    Education  YearsExperience     Salary       Location
# 0       Support Agent       Master               30  122742.69       New York
# ...

# %%
df.loc[:5,['EmployeeID', 'JobRole', 'Location']]
# Out:
#    EmployeeID          JobRole       Location
# 0           1    Support Agent       New York
# 1           2  Sales Executive  San Francisco
# 2           3    HR Specialist  San Francisco
# 3           4    Support Agent        Seattle
# 4           5          Analyst         Austin
# 5           6  Sales Executive        Chicago

# %%
df.iloc[:3,[0,-2,-1]]
# Out:
#    EmployeeID     Salary       Location
# 0           1  122742.69       New York
# 1           2  104578.37  San Francisco
# 2           3  102497.36  San Francisco

# %%
edaDf=df.groupby('Department').agg({'EmployeeID':'count','Salary':'mean'}).round(2)#also give me a way to return 2 decimal places#assuming EmplyeeID's are not duplicated, you can give me  ways to find unique values other than thids way if you can 
edaDf.rename(columns={'EmployeeID':'NumEmployees','Salary':'AvgSalaryPerDepartment'})
# Out:
#                   NumEmployees  AvgSalaryPerDepartment
# Department
# Customer Support           834                89092.88
# Engineering                784                92789.51
# Finance                    810                89569.07
# HR                         840                89529.79
# Marketing                  891                90698.68
# Sales                      841                88222.74

# %%
training_df = pd.DataFrame({
    'EmployeeID': [1001, 1002, 1005, 1010, 1012],
    'TrainingCompleted': ['Yes', 'No', 'Yes', 'No', 'Yes']
})

# %%
df=df.merge(training_df,on='EmployeeID',how='left')

# %%
df
# Out:
#       EmployeeID    HireDate      Gender  Age        Department  \
# 0              1  2019-03-25        Male   58  Customer Support
# 1              2  2022-10-11        Male   39       Engineering
# 2              3  2020-02-03  Non-binary   39                HR
# 3              4  2015-03-21        Male   35       Engineering
# 4              5  2020-04-14        Male   56       Engineering
# ...          ...         ...         ...  ...               ...
# 4995        4996  2017-12-24  Non-binary   52       Engineering
# 4996        4997  2020-09-26      Female   63           Finance
# 4997        4998  2019-07-16      Female   50                HR
# 4998        4999  2016-03-01      Female   32             Sales
# 4999        5000  2016-04-04  Non-binary   44           Finance
#
#               JobRole    Education  YearsExperience     Salary       Location  \
# 0       Support Agent       Master               30  122742.69       New York
# ...

# %%
df[df['TrainingCompleted']=='Yes']
df = df.drop('TrainingCompleted', axis=1)

# %%
dfFilt=df[(df['Department']=='Marketing')&(df['YearsExperience']>=5)]
dfSort=dfFilt.sort_values(by=['YearsExperience','Salary'],ascending=[False,False])
dfSort
# Out:
#       EmployeeID    HireDate      Gender  Age Department          JobRole  \
# 4508        4509  2020-01-01        Male   31  Marketing          Analyst
# 2974        2975  2022-01-20        Male   28  Marketing    Support Agent
# 4060        4061  2018-07-28  Non-binary   49  Marketing    Support Agent
# 3917        3918  2022-06-23      Female   47  Marketing    Support Agent
# 471          472  2017-05-16      Female   60  Marketing  Sales Executive
# ...          ...         ...         ...  ...        ...              ...
# 3977        3978  2021-06-18        Male   50  Marketing    Support Agent
# 3852        3853  2016-05-05        Male   49  Marketing         Engineer
# 685          686  2019-09-20        Male   56  Marketing          Analyst
# 971          972  2015-03-23      Female   34  Marketing          Manager
# 4377        4378  2021-02-28  Non-binary   22  Marketing  Sales Executive
#
#         Education  YearsExperience     Salary       Location
# ...

# %%
# Select top 10 from the sorted, filtered data
top10 = dfSort.head(10)

# Plot horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='EmployeeID', y='Salary', data=top10, palette='viridis')
plt.title('Top 10 Marketing Employees (≥5 Years Experience) by Salary')
plt.xlabel('Salary')
plt.ylabel('Employee ID')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9868\2663872837.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='EmployeeID', y='Salary', data=top10, palette='viridis')

# %%
df[(df['Department']=='Engineering')&(df['YearsExperience']>10)]
# Out:
#       EmployeeID    HireDate      Gender  Age   Department        JobRole  \
# 3              4  2015-03-21        Male   35  Engineering  Support Agent
# 8              9  2015-02-23      Female   60  Engineering  Support Agent
# 22            23  2019-08-19        Male   38  Engineering        Manager
# 23            24  2020-03-15      Female   55  Engineering  HR Specialist
# 42            43  2018-11-28  Non-binary   32  Engineering        Analyst
# ...          ...         ...         ...  ...          ...            ...
# 4961        4962  2017-10-23  Non-binary   51  Engineering  Support Agent
# 4970        4971  2016-12-09      Female   49  Engineering  HR Specialist
# 4973        4974  2018-10-18  Non-binary   35  Engineering  Support Agent
# 4976        4977  2018-11-18  Non-binary   42  Engineering        Manager
# 4995        4996  2017-12-24  Non-binary   52  Engineering  Support Agent
#
#         Education  YearsExperience     Salary       Location
# ...

# %%
sns.boxplot(x='Department',y='Salary',data=df,palette='viridis')
plt.title('Distribution of Salaries across Departments')
plt.figure(figsize=(10,10))
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9868\3037099305.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Department',y='Salary',data=df,palette='viridis')

# %%
df.sort_values(by=(['Department','Salary']),ascending=[True,False])
# Out:
#       EmployeeID    HireDate      Gender  Age        Department  \
# 3616        3617  2021-07-18      Female   53  Customer Support
# 1207        1208  2021-11-19      Female   52  Customer Support
# 912          913  2015-02-05  Non-binary   45  Customer Support
# 2774        2775  2015-04-06        Male   22  Customer Support
# 1537        1538  2015-07-08  Non-binary   38  Customer Support
# ...          ...         ...         ...  ...               ...
# 1761        1762  2019-08-15      Female   31             Sales
# 2851        2852  2019-02-11        Male   48             Sales
# 3392        3393  2017-04-06      Female   26             Sales
# 4795        4796  2021-07-05        Male   38             Sales
# 3688        3689  2015-01-03  Non-binary   39             Sales
#
#               JobRole    Education  YearsExperience     Salary  Location
# 3616          Manager  High School               17  149650.49   Chicago
# ...

# %%
top_earners = (
    df.sort_values(by=['Department', 'Salary'], ascending=[True, False])
      .groupby('Department')
      .head(3)
)
top_earners
# Out:
#       EmployeeID    HireDate      Gender  Age        Department  \
# 3616        3617  2021-07-18      Female   53  Customer Support
# 1207        1208  2021-11-19      Female   52  Customer Support
# 912          913  2015-02-05  Non-binary   45  Customer Support
# 2397        2398  2019-07-05      Female   24       Engineering
# 2135        2136  2017-01-31        Male   57       Engineering
# 4800        4801  2020-12-04        Male   63       Engineering
# 3535        3536  2017-05-23  Non-binary   28           Finance
# 1981        1982  2022-06-15      Female   41           Finance
# 3714        3715  2019-07-18      Female   37           Finance
# 1768        1769  2020-08-14  Non-binary   28                HR
# 4296        4297  2021-11-11      Female   44                HR
# 1663        1664  2022-11-01        Male   54                HR
# 3146        3147  2019-10-21        Male   41         Marketing
# 3599        3600  2015-02-01        Male   25         Marketing
# ...

# %%
df.sort_values(by=['Gender','Salary'],ascending=[True,False]).groupby('Gender').head(3)
# Out:
#       EmployeeID    HireDate      Gender  Age        Department  \
# 2397        2398  2019-07-05      Female   24       Engineering
# 3616        3617  2021-07-18      Female   53  Customer Support
# 412          413  2017-01-18      Female   28             Sales
# 3681        3682  2016-04-03        Male   58             Sales
# 2135        2136  2017-01-31        Male   57       Engineering
# 4800        4801  2020-12-04        Male   63       Engineering
# 1768        1769  2020-08-14  Non-binary   28                HR
# 2330        2331  2020-02-28  Non-binary   26             Sales
# 3535        3536  2017-05-23  Non-binary   28           Finance
#
#               JobRole    Education  YearsExperience     Salary       Location
# 2397          Analyst       Master               22  149901.17  San Francisco
# 3616          Manager  High School               17  149650.49        Chicago
# 412   Sales Executive  High School               14  149641.45       New York
# ...

# %%
df.filter(items=['EmployeeID','Department','Salary','YearsExperiance'])
# Out:
#       EmployeeID        Department     Salary
# 0              1  Customer Support  122742.69
# 1              2       Engineering  104578.37
# 2              3                HR  102497.36
# 3              4       Engineering   39205.72
# 4              5       Engineering   89065.50
# ...          ...               ...        ...
# 4995        4996       Engineering  119912.22
# 4996        4997           Finance  136004.38
# 4997        4998                HR  114401.45
# 4998        4999             Sales  110986.10
# 4999        5000           Finance   71916.53
#
# [5000 rows x 3 columns]

# %%
df['HireDate']=pd.to_datetime(df['HireDate'])
df['HireDate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5000 entries, 0 to 4999
# Series name: HireDate
# Non-Null Count  Dtype
# --------------  -----
# 5000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 39.2 KB

# %%
df['MonthOfHire']=df['HireDate'].dt.strftime('%B')
df['YearOfHire']=df['HireDate'].dt.year

# %%
df
# Out:
#       EmployeeID   HireDate      Gender  Age        Department  \
# 0              1 2019-03-25        Male   58  Customer Support
# 1              2 2022-10-11        Male   39       Engineering
# 2              3 2020-02-03  Non-binary   39                HR
# 3              4 2015-03-21        Male   35       Engineering
# 4              5 2020-04-14        Male   56       Engineering
# ...          ...        ...         ...  ...               ...
# 4995        4996 2017-12-24  Non-binary   52       Engineering
# 4996        4997 2020-09-26      Female   63           Finance
# 4997        4998 2019-07-16      Female   50                HR
# 4998        4999 2016-03-01      Female   32             Sales
# 4999        5000 2016-04-04  Non-binary   44           Finance
#
#               JobRole    Education  YearsExperience     Salary       Location  \
# 0       Support Agent       Master               30  122742.69       New York
# ...

# %%
lDf=df.groupby(['YearOfHire','MonthOfHire'],as_index=False).agg({'EmployeeID':'count'})
months_of_year=['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['MonthOfHire']=pd.Categorical(df['MonthOfHire'],categories=months_of_year,ordered=True)
lDf.sort_values(by=['YearOfHire','MonthOfHire'],inplace=True)

# %%
lDf
# Out:
#     YearOfHire MonthOfHire  EmployeeID
# 4         2015     January          43
# 3         2015    February          51
# 7         2015       March          58
# 0         2015       April          45
# 8         2015         May          60
# ..         ...         ...         ...
# 85        2022      August          50
# 95        2022   September          62
# 94        2022     October          44
# 93        2022    November          40
# 86        2022    December          54
#
# [96 rows x 3 columns]

# %%
plt.style.use('tableau-colorblind10')
lDf[lDf['YearOfHire']==2019].plot(kind='line',y='EmployeeID',x='MonthOfHire',title='Employees Hired Over The Year Of 2019',ylabel='Number Of Employees',xlabel='Months(2019)',color='green')
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=lDf, x='MonthOfHire', y='EmployeeID', hue='YearOfHire', marker='o')
plt.title('Monthly Hiring Trends by Year')
plt.xlabel('Month')
plt.subplots()
plt.ylabel('Employees Hired')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
lDf
# Out:
#     YearOfHire MonthOfHire  EmployeeID
# 4         2015     January          43
# 3         2015    February          51
# 7         2015       March          58
# 0         2015       April          45
# 8         2015         May          60
# ..         ...         ...         ...
# 85        2022      August          50
# 95        2022   September          62
# 94        2022     October          44
# 93        2022    November          40
# 86        2022    December          54
#
# [96 rows x 3 columns]

# %%
df.sort_values(by='MonthOfHire')
# Out:
#       EmployeeID   HireDate      Gender  Age        Department  \
# 2499        2500 2017-01-10        Male   63             Sales
# 832          833 2017-01-26      Female   46  Customer Support
# 3674        3675 2022-01-14  Non-binary   25                HR
# 3688        3689 2015-01-03  Non-binary   39             Sales
# 3691        3692 2017-01-14  Non-binary   22         Marketing
# ...          ...        ...         ...  ...               ...
# 2438        2439 2019-12-26      Female   62         Marketing
# 2450        2451 2018-12-13  Non-binary   43           Finance
# 3551        3552 2018-12-10  Non-binary   38             Sales
# 4697        4698 2019-12-02      Female   58       Engineering
# 2692        2693 2015-12-12        Male   64                HR
#
#               JobRole    Education  YearsExperience     Salary       Location  \
# 2499          Analyst       Master                0   31160.11        Seattle
# ...

# %%
avgDf=df.groupby('YearOfHire',as_index=False).agg({'Salary':'mean'}).rename(columns={'Salary':'AvgSalary'}).round(2)
avgDf.plot(kind='line',x='YearOfHire',y='AvgSalary',title='Average Salary Over The Years',ylabel='Average Salary($)',xlabel='Years')
plt.show()

# %%
sDf=df['Salary']
sns.histplot(data=sDf,bins=25,kde=True,color='green')
plt.show()#rate this histogram

# %%
sDf=df.groupby('YearsExperience',as_index=False).agg({'Salary':'mean'})#avaerage the salries for each yearexperiance ,to prevent cluttering
sns.scatterplot(data=sDf,x='YearsExperience',y='Salary')
plt.show()

# %%
correlation = df['YearsExperience'].corr(df['Salary'])
print(f"Correlation between Years of Experience and Salary: {correlation:.2f}")
# Out:
# Correlation between Years of Experience and Salary: -0.01

# %%
# Select relevant numerical columns
num_cols = ['Age', 'YearsExperience', 'Salary']  # Adjust as needed
corr_matrix = df[num_cols].corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Employee Metrics")
plt.tight_layout()
plt.show()
