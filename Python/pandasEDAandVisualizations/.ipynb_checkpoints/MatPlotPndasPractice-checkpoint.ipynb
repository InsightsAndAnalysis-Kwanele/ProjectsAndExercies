# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('sales_data.csv')
print(df)
# Out:
#      OrderID CustomerName     Product     Category  Quantity  UnitPrice  \
# 0       1001        Diana       Mouse  Electronics         9     168.15
# 1       1002          Eve    Keyboard  Electronics         9     442.96
# 2       1003      Charlie       Mouse  Accessories         9     518.22
# 3       1004          Eve       Mouse  Accessories         7     434.08
# 4       1005          Eve     Monitor  Electronics         2     554.39
# ..       ...          ...         ...          ...       ...        ...
# 995     1996        Frank    Keyboard  Electronics         6     169.21
# 996     1997          Eve      Laptop  Accessories         8     784.13
# 997     1998        Alice    Keyboard  Accessories         2     275.09
# 998     1999        Alice  Smartphone  Accessories         6     693.52
# 999     2000          Eve      Tablet  Accessories         1     587.49
#
#       OrderDate Region  TotalPrice
# 0    2023-02-25   East     1513.35
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.sort_values(by=['Region','TotalPrice'],ascending=[True,False])#how do you make it that all rows show in the data frame
# Out:
#      OrderID CustomerName     Product     Category  Quantity  UnitPrice  \
# 410     1411      Charlie     Monitor  Accessories         9     978.16
# 156     1157      Charlie  Smartphone  Accessories         9     922.51
# 303     1304        Alice      Laptop  Accessories         9     869.51
# 904     1905          Bob    Keyboard  Electronics         8     953.87
# 472     1473          Eve  Smartphone  Accessories         9     833.51
# 445     1446          Eve  Smartphone  Electronics         9     831.83
# 62      1063      Charlie      Tablet  Accessories         9     820.57
# 19      1020        Diana  Smartphone  Accessories         9     816.80
# 888     1889        Diana     Monitor  Electronics         8     895.04
# 429     1430      Charlie     Monitor  Accessories         8     883.60
# 937     1938        Frank      Tablet  Electronics         8     880.37
# 562     1563          Eve     Monitor  Electronics         8     877.00
# ...

# %%
df.filter(items=['CustomerName', 'Product', 'TotalPrice'])
# Out:
#     CustomerName     Product  TotalPrice
# 0          Diana       Mouse     1513.35
# 1            Eve    Keyboard     3986.64
# 2        Charlie       Mouse     4663.98
# 3            Eve       Mouse     3038.56
# 4            Eve     Monitor     1108.78
# 5            Bob       Mouse     3076.90
# 6        Charlie  Smartphone      237.72
# 7        Charlie       Mouse     3927.12
# 8        Charlie       Mouse     1930.64
# 9            Eve       Mouse     3258.48
# 10         Diana      Laptop     3468.35
# 11       Charlie  Smartphone      692.54
# 12         Frank  Smartphone      785.29
# 13           Eve    Keyboard     6274.24
# 14           Bob     Monitor     1090.46
# 15         Diana       Mouse     6840.47
# 16         Frank      Tablet     1523.43
# 17         Frank     Monitor      594.90
# 18           Bob     Monitor     6253.20
# 19         Diana  Smartphone     7351.20
# 20           Eve     Monitor      328.40
# 21         Alice       Mouse     1813.80
# ...

# %%
df.loc[:4,['CustomerName', 'Product', 'TotalPrice']]
# Out:
#   CustomerName   Product  TotalPrice
# 0        Diana     Mouse     1513.35
# 1          Eve  Keyboard     3986.64
# 2      Charlie     Mouse     4663.98
# 3          Eve     Mouse     3038.56
# 4          Eve   Monitor     1108.78

# %%
df.iloc[:4,[0,3,-1]]
# Out:
#    OrderID     Category  TotalPrice
# 0     1001  Electronics     1513.35
# 1     1002  Electronics     3986.64
# 2     1003  Accessories     4663.98
# 3     1004  Accessories     3038.56

# %%
print('Total price in each region')
df.groupby('Region').agg({'TotalPrice':'sum'})
# Out:
# Total price in each region
#         TotalPrice
# Region
# East     704082.93
# North    666696.33
# South    665259.61
# West     604179.51

# %%
df
# Out:
#      OrderID CustomerName     Product     Category  Quantity  UnitPrice  \
# 0       1001        Diana       Mouse  Electronics         9     168.15
# 1       1002          Eve    Keyboard  Electronics         9     442.96
# 2       1003      Charlie       Mouse  Accessories         9     518.22
# 3       1004          Eve       Mouse  Accessories         7     434.08
# 4       1005          Eve     Monitor  Electronics         2     554.39
# 5       1006          Bob       Mouse  Accessories         5     615.38
# 6       1007      Charlie  Smartphone  Electronics         4      59.43
# 7       1008      Charlie       Mouse  Electronics         8     490.89
# 8       1009      Charlie       Mouse  Electronics         2     965.32
# 9       1010          Eve       Mouse  Electronics         6     543.08
# 10      1011        Diana      Laptop  Accessories         5     693.67
# 11      1012      Charlie  Smartphone  Electronics         2     346.27
# ...

# %%
edaDf=df.groupby('Category').agg({'Quantity':'sum','UnitPrice':'mean','TotalPrice':'max'})
edaDf.rename(columns={'Quantity':'TotalQuantitySold','UnitPrice':'AvgUnitPrice','TotalPrice':'MaxTotalPrice'}) #you can give me simpler ways to rename the coloumns ,and give me a way to round the values to two decimal places
# Out:
#              TotalQuantitySold  AvgUnitPrice  MaxTotalPrice
# Category
# Accessories               2648    521.572877        8803.44
# Electronics               2367    522.757955        8996.22

# %%
newDf=df.groupby('Region').agg({'TotalPrice':'sum'})
print(newDf)
newDf.plot(kind='bar')
plt.show()
# Out:
#         TotalPrice
# Region
# East     704082.93
# North    666696.33
# South    665259.61
# West     604179.51

# %%
import seaborn as sns
#import matplotlib.pyplot as plt

# Prepare aggregated data
region_sales_df = df.groupby('Region', as_index=False)['TotalPrice'].sum()

# Plot
sns.barplot(data=region_sales_df, x='Region', y='TotalPrice', palette='Blues_d')
plt.title('Total Sales by Region')
plt.ylabel('Total Sales')
plt.xlabel('Region')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\FE-Lab-8\AppData\Local\Temp\ipykernel_17116\2037375502.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=region_sales_df, x='Region', y='TotalPrice', palette='Blues_d')

# %%
df
# Out:
#      OrderID CustomerName     Product     Category  Quantity  UnitPrice  \
# 0       1001        Diana       Mouse  Electronics         9     168.15
# 1       1002          Eve    Keyboard  Electronics         9     442.96
# 2       1003      Charlie       Mouse  Accessories         9     518.22
# 3       1004          Eve       Mouse  Accessories         7     434.08
# 4       1005          Eve     Monitor  Electronics         2     554.39
# 5       1006          Bob       Mouse  Accessories         5     615.38
# 6       1007      Charlie  Smartphone  Electronics         4      59.43
# 7       1008      Charlie       Mouse  Electronics         8     490.89
# 8       1009      Charlie       Mouse  Electronics         2     965.32
# 9       1010          Eve       Mouse  Electronics         6     543.08
# 10      1011        Diana      Laptop  Accessories         5     693.67
# 11      1012      Charlie  Smartphone  Electronics         2     346.27
# ...

# %%
df['OrderDate']=pd.to_datetime(df['OrderDate'])
df
# Out:
#      OrderID CustomerName     Product     Category  Quantity  UnitPrice  \
# 0       1001        Diana       Mouse  Electronics         9     168.15
# 1       1002          Eve    Keyboard  Electronics         9     442.96
# 2       1003      Charlie       Mouse  Accessories         9     518.22
# 3       1004          Eve       Mouse  Accessories         7     434.08
# 4       1005          Eve     Monitor  Electronics         2     554.39
# 5       1006          Bob       Mouse  Accessories         5     615.38
# 6       1007      Charlie  Smartphone  Electronics         4      59.43
# 7       1008      Charlie       Mouse  Electronics         8     490.89
# 8       1009      Charlie       Mouse  Electronics         2     965.32
# 9       1010          Eve       Mouse  Electronics         6     543.08
# 10      1011        Diana      Laptop  Accessories         5     693.67
# 11      1012      Charlie  Smartphone  Electronics         2     346.27
# ...

# %%
df['months'] = df['OrderDate'].dt.strftime('%B')
df
# Out:
#      OrderID CustomerName     Product     Category  Quantity  UnitPrice  \
# 0       1001        Diana       Mouse  Electronics         9     168.15
# 1       1002          Eve    Keyboard  Electronics         9     442.96
# 2       1003      Charlie       Mouse  Accessories         9     518.22
# 3       1004          Eve       Mouse  Accessories         7     434.08
# 4       1005          Eve     Monitor  Electronics         2     554.39
# 5       1006          Bob       Mouse  Accessories         5     615.38
# 6       1007      Charlie  Smartphone  Electronics         4      59.43
# 7       1008      Charlie       Mouse  Electronics         8     490.89
# 8       1009      Charlie       Mouse  Electronics         2     965.32
# 9       1010          Eve       Mouse  Electronics         6     543.08
# 10      1011        Diana      Laptop  Accessories         5     693.67
# 11      1012      Charlie  Smartphone  Electronics         2     346.27
# ...

# %%
df['OrderDate']=pd.to_datetime(df['OrderDate']) #converting to date time 
df['months'] = df['OrderDate'].dt.strftime('%B') #getting the months only


months_ordered=['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['months']=pd.Categorical(df['months'],categories=months_ordered,ordered=True)    #arranging the months in order

dfSales=df.groupby('months').agg({'TotalPrice':'sum'}) 
dfSales
dfSales.plot(kind='line',color='orange')
plt.title('Monthly Sales Trend(total sales per month)')
plt.ylabel('TotalSales')
plt.xlabel('Month')
plt.show()
# Out:
# C:\Users\FE-Lab-8\AppData\Local\Temp\ipykernel_17116\2636155575.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dfSales=df.groupby('months').agg({'TotalPrice':'sum'})
