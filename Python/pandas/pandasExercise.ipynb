# %%
import pandas as pd

df=pd.read_csv('data.csv')

#print(df.to_string())

# %%
newDf=df.dropna()
#print(newDf.info())
#print(newDf.to_string())

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
mean=round(df['Calories'].mean(),2)
print(mean)
otherDf=df.fillna(mean)
# Out:
# 375.79

# %%
print(otherDf.info())
#print(otherDf.to_string())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  169 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
#print(otherDf.head(5))

# %%
#print(otherDf.index)

# %%
for x in otherDf.index:
    if otherDf.loc[x,'Duration']>120:
        otherDf.drop(x,inplace=True)


print(otherDf.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130    409.10
# 1          60    117       145    479.00
# 2          60    103       135    340.00
# 3          45    109       175    282.40
# 4          45    117       148    406.00
# 5          60    102       127    300.00
# 6          60    110       136    374.00
# 7          45    104       134    253.30
# 8          30    109       133    195.10
# 9          60     98       124    269.00
# 10         60    103       147    329.30
# 11         60    100       120    250.70
# 12         60    106       128    345.30
# 13         60    104       132    379.30
# 14         60     98       123    275.00
# 15         60     98       120    215.20
# 16         60    100       120    300.00
# 17         45     90       112    375.79
# 18         60    103       123    323.00
# 19         45     97       125    243.00
# 20         60    108       131    364.20
# 21         45    100       119    282.00
# ...

# %%
mean=round(otherDf['Duration'].mean(),2)

print(mean)
# Out:
# 53.46

# %%
print(otherDf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 156 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  156 non-null    int64
#  1   Pulse     156 non-null    int64
#  2   Maxpulse  156 non-null    int64
#  3   Calories  156 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 10.2 KB
# None

# %%
totCalar=0
x=0
while x<7:
    totCalar+=df.loc[x,'Calories']
    x+=1
avgCalar=totCalar/7
#print(f'On the 7th day you burnt:{otherDf.loc[6,'Calories']} colories')
print()
print('Data for the first week:','\n')
print(otherDf.head(7))
print('\n'f'Total Colories burnt on the first Week:{totCalar} colaries{'\n'}Average Colories burnt per day:{avgCalar:.2f} colaries')
# Out:
# Data for the first week:
#
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
#
# Total Colories burnt on the first Week:2590.5 colaries
# Average Colories burnt per day:370.07 colaries

# %%
print(otherDf.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130    409.10
# 1          60    117       145    479.00
# 2          60    103       135    340.00
# 3          45    109       175    282.40
# 4          45    117       148    406.00
# 5          60    102       127    300.00
# 6          60    110       136    374.00
# 7          45    104       134    253.30
# 8          30    109       133    195.10
# 9          60     98       124    269.00
# 10         60    103       147    329.30
# 11         60    100       120    250.70
# 12         60    106       128    345.30
# 13         60    104       132    379.30
# 14         60     98       123    275.00
# 15         60     98       120    215.20
# 16         60    100       120    300.00
# 17         45     90       112    375.79
# 18         60    103       123    323.00
# 19         45     97       125    243.00
# 20         60    108       131    364.20
# 21         45    100       119    282.00
# ...
