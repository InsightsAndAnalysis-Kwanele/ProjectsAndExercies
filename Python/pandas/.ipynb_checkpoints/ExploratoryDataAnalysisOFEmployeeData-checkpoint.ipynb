# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('employee_data (1).csv')
df.head(5)
# Out:
#      EmployeeID           Name  Age      Gender  Department     JobRole  \
# 0         10001     Employee_1   50      Female          HR     Manager
# 1         10002     Employee_2   36      Female  Operations     Manager
# 2         10003     Employee_3   29        Male  Operations     Manager
# 3         10004     Employee_4   42      Female         R&D     Manager
# 4         10005     Employee_5   40      Female  Operations     Analyst
# ..          ...            ...  ...         ...         ...         ...
# 995       10996   Employee_996   34  Non-Binary  Operations     Analyst
# 996       10997   Employee_997   51      Female          IT   Executive
# 997       10998   Employee_998   44        Male       Sales     Manager
# 998       10999   Employee_999   40      Female     Finance  Technician
# 999       11000  Employee_1000   53        Male  Operations    Engineer
#
#        Education  YearsAtCompany  YearsInCurrentRole  TrainingHoursLastYear  \
# 0     Bachelor's              21                   0                     16
# 1     Bachelor's               1                   1                     34
# 2     Bachelor's              12                  13                     45
# 3    High School               4                  14                     41
# 4     Bachelor's              27                  11                     38
# ..           ...             ...                 ...                    ...
# 995     Master's              28                   1                     47
# 996     Master's              29                   9                     24
# 997     Master's              19                   0                     56
# 998   Bachelor's              16                   6                     34
# 999     Master's              12                   9                     75
#
#      MonthlyIncome  JobSatisfaction  PerformanceRating Attrition
# 0             4017                3                  2        No
# 1             9957                2                  4        No
# 2            18230                3                  3        No
# 3            11420                1                  4        No
# 4             6792                1                  3       Yes
# ..             ...              ...                ...       ...
# 995           5621                1                  4        No
# 996           6491                2                  3        No
# 997          17916                4                  3       Yes
# 998          17248                3                  2       Yes
# 999           4511                1                  3        No
#
# [1000 rows x 14 columns]

# %%
print(df.head(5))# first 5 rows
print()
print('Rows and Columns(Shape)')
print(df.shape)
print()
print('Table info')
print(df.info())
# Out:
#    EmployeeID        Name  Age  Gender  Department  JobRole    Education  \
# 0       10001  Employee_1   50  Female          HR  Manager   Bachelor's
# 1       10002  Employee_2   36  Female  Operations  Manager   Bachelor's
# 2       10003  Employee_3   29    Male  Operations  Manager   Bachelor's
# 3       10004  Employee_4   42  Female         R&D  Manager  High School
# 4       10005  Employee_5   40  Female  Operations  Analyst   Bachelor's
#
#    YearsAtCompany  YearsInCurrentRole  TrainingHoursLastYear  MonthlyIncome  \
# 0              21                   0                     16           4017
# 1               1                   1                     34           9957
# 2              12                  13                     45          18230
# 3               4                  14                     41          11420
# 4              27                  11                     38           6792
#
#    JobSatisfaction  PerformanceRating Attrition
# 0                3                  2        No
# 1                2                  4        No
# 2                3                  3        No
# 3                1                  4        No
# 4                1                  3       Yes
#
# Rows and Columns(Shape)
# (1000, 14)
#
# Table info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EmployeeID             1000 non-null   int64
#  1   Name                   1000 non-null   object
#  2   Age                    1000 non-null   int64
#  3   Gender                 1000 non-null   object
#  4   Department             1000 non-null   object
#  5   JobRole                1000 non-null   object
#  6   Education              1000 non-null   object
#  7   YearsAtCompany         1000 non-null   int64
#  8   YearsInCurrentRole     1000 non-null   int64
#  9   TrainingHoursLastYear  1000 non-null   int64
#  10  MonthlyIncome          1000 non-null   int64
#  11  JobSatisfaction        1000 non-null   int64
#  12  PerformanceRating      1000 non-null   int64
#  13  Attrition              1000 non-null   object
# dtypes: int64(8), object(6)
# memory usage: 109.5+ KB
# None

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# Name                     0
# Age                      0
# Gender                   0
# Department               0
# JobRole                  0
# Education                0
# YearsAtCompany           0
# YearsInCurrentRole       0
# TrainingHoursLastYear    0
# MonthlyIncome            0
# JobSatisfaction          0
# PerformanceRating        0
# Attrition                0
# dtype: int64

# %%
df
# Out:
#      EmployeeID           Name  Age      Gender  Department     JobRole  \
# 0         10001     Employee_1   50      Female          HR     Manager
# 1         10002     Employee_2   36      Female  Operations     Manager
# 2         10003     Employee_3   29        Male  Operations     Manager
# 3         10004     Employee_4   42      Female         R&D     Manager
# 4         10005     Employee_5   40      Female  Operations     Analyst
# ..          ...            ...  ...         ...         ...         ...
# 995       10996   Employee_996   34  Non-Binary  Operations     Analyst
# 996       10997   Employee_997   51      Female          IT   Executive
# 997       10998   Employee_998   44        Male       Sales     Manager
# 998       10999   Employee_999   40      Female     Finance  Technician
# 999       11000  Employee_1000   53        Male  Operations    Engineer
#
#        Education  YearsAtCompany  YearsInCurrentRole  TrainingHoursLastYear  \
# 0     Bachelor's              21                   0                     16
# 1     Bachelor's               1                   1                     34
# 2     Bachelor's              12                  13                     45
# 3    High School               4                  14                     41
# 4     Bachelor's              27                  11                     38
# ..           ...             ...                 ...                    ...
# 995     Master's              28                   1                     47
# 996     Master's              29                   9                     24
# 997     Master's              19                   0                     56
# 998   Bachelor's              16                   6                     34
# 999     Master's              12                   9                     75
#
#      MonthlyIncome  JobSatisfaction  PerformanceRating Attrition
# 0             4017                3                  2        No
# 1             9957                2                  4        No
# 2            18230                3                  3        No
# 3            11420                1                  4        No
# 4             6792                1                  3       Yes
# ..             ...              ...                ...       ...
# 995           5621                1                  4        No
# 996           6491                2                  3        No
# 997          17916                4                  3       Yes
# 998          17248                3                  2       Yes
# 999           4511                1                  3        No
#
# [1000 rows x 14 columns]

# %%
# Descriptive statistics for numerical columns
print(df.describe())

# Value counts for the 'Attrition' column
print('\nValue counts in the Attrition column:')
print(df['Attrition'].value_counts())

# Unique values in each column
print('\nNumber of unique values in each column:')
print(df.nunique())
# Out:
#          EmployeeID          Age  YearsAtCompany  YearsInCurrentRole  \
# count   1000.000000  1000.000000     1000.000000         1000.000000
# mean   10500.500000    40.947000       15.101000            6.832000
# std      288.819436    11.160858        8.416153            4.273879
# min    10001.000000    22.000000        0.000000            0.000000
# 25%    10250.750000    31.000000        8.000000            3.000000
# 50%    10500.500000    42.000000       15.000000            7.000000
# 75%    10750.250000    50.000000       22.000000           10.000000
# max    11000.000000    59.000000       29.000000           14.000000
#
#        TrainingHoursLastYear  MonthlyIncome  JobSatisfaction  \
# count            1000.000000    1000.000000      1000.000000
# mean               40.421000   11056.855000         2.465000
# std                23.099033    5177.626701         1.120728
# min                 0.000000    2021.000000         1.000000
# 25%                21.000000    6517.750000         1.000000
# 50%                41.000000   11269.000000         2.000000
# 75%                61.000000   15453.250000         3.000000
# max                79.000000   19953.000000         4.000000
#
#        PerformanceRating
# count        1000.000000
# mean            2.453000
# std             1.140654
# min             1.000000
# 25%             1.000000
# 50%             2.000000
# 75%             3.000000
# max             4.000000
#
# Value counts in the Attrition column:
# Attrition
# No     791
# Yes    209
# Name: count, dtype: int64
#
# Number of unique values in each column:
# EmployeeID               1000
# Name                     1000
# Age                        38
# Gender                      3
# Department                  6
# JobRole                     6
# Education                   4
# YearsAtCompany             30
# YearsInCurrentRole         15
# TrainingHoursLastYear      80
# MonthlyIncome             968
# JobSatisfaction             4
# PerformanceRating           4
# Attrition                   2
# dtype: int64

# %%
df
# Out:
#      EmployeeID           Name  Age      Gender  Department     JobRole  \
# 0         10001     Employee_1   50      Female          HR     Manager
# 1         10002     Employee_2   36      Female  Operations     Manager
# 2         10003     Employee_3   29        Male  Operations     Manager
# 3         10004     Employee_4   42      Female         R&D     Manager
# 4         10005     Employee_5   40      Female  Operations     Analyst
# ..          ...            ...  ...         ...         ...         ...
# 995       10996   Employee_996   34  Non-Binary  Operations     Analyst
# 996       10997   Employee_997   51      Female          IT   Executive
# 997       10998   Employee_998   44        Male       Sales     Manager
# 998       10999   Employee_999   40      Female     Finance  Technician
# 999       11000  Employee_1000   53        Male  Operations    Engineer
#
#        Education  YearsAtCompany  YearsInCurrentRole  TrainingHoursLastYear  \
# 0     Bachelor's              21                   0                     16
# 1     Bachelor's               1                   1                     34
# 2     Bachelor's              12                  13                     45
# 3    High School               4                  14                     41
# 4     Bachelor's              27                  11                     38
# ..           ...             ...                 ...                    ...
# 995     Master's              28                   1                     47
# 996     Master's              29                   9                     24
# 997     Master's              19                   0                     56
# 998   Bachelor's              16                   6                     34
# 999     Master's              12                   9                     75
#
#      MonthlyIncome  JobSatisfaction  PerformanceRating Attrition
# 0             4017                3                  2        No
# 1             9957                2                  4        No
# 2            18230                3                  3        No
# 3            11420                1                  4        No
# 4             6792                1                  3       Yes
# ..             ...              ...                ...       ...
# 995           5621                1                  4        No
# 996           6491                2                  3        No
# 997          17916                4                  3       Yes
# 998          17248                3                  2       Yes
# 999           4511                1                  3        No
#
# [1000 rows x 14 columns]

# %%
dfStats=df.groupby('Age',as_index=False).agg({'MonthlyIncome':'mean'}) # getting the average salary per age group
sns.scatterplot(data=dfStats,x='MonthlyIncome',y='Age',color='orange')#how do I get a line to show between the points
plt.title('Relationship between Age and MonthlyIncome')
plt.show()

# %%
sns.countplot(data=df,x='Attrition')
plt.title('Attrition(No vs Yes)')
plt.show()

sns.histplot(data=df,x=df['MonthlyIncome'],kde=True,color='green',bins=30)
plt.title('Distribution of MonthlyIncomes of Employees')
plt.show()

sns.boxplot(data=df,x='Age')
plt.title('Spread Of Different Age groups')
plt.show()

# %%
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
