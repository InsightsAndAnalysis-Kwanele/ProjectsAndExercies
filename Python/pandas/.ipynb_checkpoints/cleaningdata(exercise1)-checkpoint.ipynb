# %%
import pandas as pd
import csv 


file= pd.read_csv('data.csv') 

print(file.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
cleanFile=file.dropna()
print(cleanFile.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
file['Calories'].fillna(130,inplace=True)

print(file.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     130.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
mode=file['Calories'].mode()[0]
mean=round(file['Calories'].mean(),2)
midian=file['Calories'].median()
print(mode)
print(f'{mean:.2f}')
print(midian)
# Out:
# 300.0
# 375.79
# 318.6

# %%
file['Calories'].fillna(mean,inplace=True)
print(file.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130    409.10
# 1          60    117       145    479.00
# 2          60    103       135    340.00
# 3          45    109       175    282.40
# 4          45    117       148    406.00
# 5          60    102       127    300.00
# 6          60    110       136    374.00
# 7          45    104       134    253.30
# 8          30    109       133    195.10
# 9          60     98       124    269.00
# 10         60    103       147    329.30
# 11         60    100       120    250.70
# 12         60    106       128    345.30
# 13         60    104       132    379.30
# 14         60     98       123    275.00
# 15         60     98       120    215.20
# 16         60    100       120    300.00
# 17         45     90       112    375.79
# 18         60    103       123    323.00
# 19         45     97       125    243.00
# 20         60    108       131    364.20
# 21         45    100       119    282.00
# ...
