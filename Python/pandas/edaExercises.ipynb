# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('tips')  # Restaurant bill tips dataset
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='day', y='total_bill', data=df)
plt.title('Average Bill per Day')
plt.show()

# %%
sns.scatterplot(x='total_bill', y='tip', data=df)
#plt.title('Tip vs Total Bill')
#plt.show()
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(x='day', y='total_bill', data=df)
plt.title('Bill Distribution by Day')
plt.show()

# %%
df=pd.read_csv("Downloads/monthly_sales.csv")
df
# Out:
#   Month  Sales
# 0   Jan   1000
# 1   Feb   1500
# 2   Mar   1300
# 3   Apr   1700
# 4   May   1600

# %%
xAxis=df['Month']
yAxis=df['Sales']
plt.hist(yAxis,bins=5,color='green',edgecolor='black')
plt.title('Monthly Sales')
plt.xlabel('Months')
plt.ylabel('Sales($)')
plt.grid(True)
plt.show()

# %%
data = {
    'HR': [40000, 42000, 45000, 47000, 49000],
    'IT': [60000, 62000, 65000, 68000, 70000],
    'Sales': [50000, 51000, 53000, 55000, 56000]
}

plt.boxplot(data.values(), labels=data.keys())
plt.title('Salary Distribution by Department')
plt.ylabel('Salary ($)')
plt.grid(True)
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13060\3498542644.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data.values(), labels=data.keys())

# %%
import seaborn as sns

sns.barplot(x='day', y='total_bill', data=df)
plt.title('Average Bill per Day')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 import seaborn as sns
# ----> 3 sns.barplot(x='day', y='total_bill', data=df)
#       4 plt.title('Average Bill per Day')
#       5 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
# ...
